# %%
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np
import time
import json
import concurrent.futures 
from multiprocessing.dummy import Pool as pool
import re
import random
from lxml import etree

# %%
r = rq.get('https://autumnfish.cn/playlist/detail?id=2829883282')
data = r.text
print(data)
# Out:
# {"code":200,"relatedVideos":null,"playlist":{"subscribers":[{"defaultAvatar":true,"province":350000,"authStatus":0,"followed":false,"avatarUrl":"http://p1.music.126.net/RLeBJe4D1ZzUtltxfoKDMg==/109951163250239066.jpg","accountStatus":0,"gender":0,"city":350200,"birthday":-2209017600000,"userId":1853462382,"userType":0,"nickname":"小小邱邱1","signature":"","description":"","detailDescription":"","avatarImgId":109951163250239070,"backgroundImgId":109951162868126480,"backgroundUrl":"http://p1.music.126.net/_f8R60U9mZ42sSNvdPn2sQ==/109951162868126486.jpg","authority":0,"mutual":false,"expertTags":null,"experts":null,"djStatus":0,"vipType":0,"remarkName":null,"authenticationTypes":0,"avatarDetail":null,"avatarImgIdStr":"109951163250239066","backgroundImgIdStr":"109951162868126486","anchor":false,"avatarImgId_str":"109951163250239066"},{"defaultAvatar":true,"province":0,"authStatus":0,"followed":false,"avatarUrl":"http://p1.music.126.net/ma8NC_MpYqC-dK_L81FWXQ==/109951163250233892.jpg","accountStatus":0,"gender":1,"city":100,"birthday":-2209017600000,"userId":4013013204,"userType":0,"nickname":"用户4013022816","signature":"","description":"","detailDescription":"","avatarImgId":109951163250233890,"backgroundImgId":109951162868126480,"backgroundUrl":"http://p1.music.126.net/_f8R60U9mZ42sSNvdPn2sQ==/109951162868126486.jpg","authority":0,"mutual":false,"expertTags":null,"experts":null,"djStatus":0,"vipType":0,"remarkName":null,"authenticationTypes":0,"avatarDetail":null,"avatarImgIdStr":"109951163250233892","backgroundImgIdStr":"109951162868126486","anchor":false,"avatarImgId_str":"109951163250233892"},{"defaultAvatar":false,"province":340000,"authStatus":0,"followed":false,"avatarUrl":"http://p1.music.126.net/eT9YERMFQNnJNS5n5luN1Q==/109951164906682042.jpg","accountStatus":0,"gender":1,"city":340100,"birthday":-2209017600000,"userId":3295445735,"userType":0,"nickname":"盼期待等","signature":"","description":"","detailDescription":"","avatarImgId":109951164906682050,"backgroundImgId":109951165526602690,"backgroundUrl":"http://p1.music.126.net/ZiwBGSaxdh9IJU-HctpSVA==/109951165526602691.jpg","authority":0,"mutual":false,"expertTags":null,"experts":null,"djStatus":0,"vipType":0,"remarkName":null,"authenticationTypes":0,"avatarDetail":null,"avatarImgIdStr":"109951164906682042","backgroundImgIdStr":"109951165526602691","anchor":false,"avatarImgId_str":"109951164906682042"},{"defaultAvatar":false,"province":330000,"authStatus":0,"followed":false,"avatarUrl":"http://p1.music.126.net/8u3o5wnKUTH1eexT0wBWgQ==/18501482162277502.jpg","accountStatus":0,"gender":2,"city":330400,"birthday":-2209017600000,"userId":426049574,"userType":0,"nickname":"Yuniskii","signature":"","description":"","detailDescription":"","avatarImgId":18501482162277504,"backgroundImgId":2002210674180198,"backgroundUrl":"http://p1.music.126.net/i0qi6mibX8gq2SaLF1bYbA==/2002210674180198.jpg","authority":0,"mutual":false,"expertTags":null,"experts":null,"djStatus":0,"vipType":11,"remarkName":null,"authenticationTypes":0,"avatarDetail":null,"avatarImgIdStr":"18501482162277502","backgroundImgIdStr":"2002210674180198","anchor":false,"avatarImgId_str":"18501482162277502"},{"defaultAvatar":false,"province":620000,"authStatus":0,"followed":false,"avatarUrl":"http://p1.music.126.net/cxR9h7FrURzRP6c6qGdv6Q==/109951163131978404.jpg","accountStatus":0,"gender":1,"city":620100,"birthday":-2209017600000,"userId":1361867123,"userType":0,"nickname":"M-iron","signature":"","description":"","detailDescription":"","avatarImgId":109951163131978400,"backgroundImgId":109951162868126480,"backgroundUrl":"http://p1.music.126.net/_f8R60U9mZ42sSNvdPn2sQ==/109951162868126486.jpg","authority":0,"mutual":false,"expertTags":null,"experts":null,"djStatus":0,"vipType":10,"remarkName":null,"authenticationTypes":0,"avatarDetail":null,"avatarImgIdStr":"109951163131978404","backgroundImgIdStr":"109951162868126486","anchor":false,"avatarImgId_str":"109951163131978404"},{"defaultAvatar":false,"province":110000,"authStatus": ...

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
data_dict = json.loads(data)

# %%
data_dict.get('playlist').get('id')
# Out:
# 2829883282

# %%
data_json = json.dumps(data_dict, indent=3, ensure_ascii=False)

# %%
print(data_json)
# Out:
# {
#    "code": 200,
#    "relatedVideos": null,
#    "playlist": {
#       "subscribers": [
#          {
#             "defaultAvatar": true,
#             "province": 350000,
#             "authStatus": 0,
#             "followed": false,
#             "avatarUrl": "http://p1.music.126.net/RLeBJe4D1ZzUtltxfoKDMg==/109951163250239066.jpg",
#             "accountStatus": 0,
#             "gender": 0,
#             "city": 350200,
#             "birthday": -2209017600000,
#             "userId": 1853462382,
#             "userType": 0,
#             "nickname": "小小邱邱1",
#             "signature": "",
#             "description": "",
#             "detailDescription": "",
#             "avatarImgId": 109951163250239070,
#             "backgroundImgId": 109951162868126480,
#             "backgroundUrl": "http://p1.music.126.net/_f8R60U9mZ42sSNvdPn2sQ==/109951162868126486.jpg",
#             "authority": 0,
#             "mutual": false,
#             "expertTags": null,
#             "experts": null,
#             "djStatus": 0,
#             "vipType": 0,
#             "remarkName": null,
#             "authenticationTypes": 0,
#             "avatarDetail": null,
#             "avatarImgIdStr": "109951163250239066",
#             "backgroundImgIdStr": "109951162868126486",
#             "anchor": false,
#             "avatarImgId_str": "109951163250239066"
#          },
#          {
#             "defaultAvatar": true,
#             "province": 0,
#             "authStatus": 0,
#             "followed": false,
#             "avatarUrl": "http://p1.music.126.net/ma8NC_MpYqC-dK_L81FWXQ==/109951163250233892.jpg",
#             "accountStatus": 0,
#             "gender": 1,
#             "city": 100,
#             "birthday": -2209017600000,
#             "userId": 4013013204,
#             "userType": 0,
#             "nickname": "用户4013022816",
#             "signature": "",
#             "description": "",
#             "detailDescription": "",
#             "avatarImgId": 109951163250233890,
#             "backgroundImgId": 109951162868126480,
#             "backgroundUrl": "http://p1.music.126.net/_f8R60U9mZ42sSNvdPn2sQ==/109951162868126486.jpg",
#             "authority": 0,
#             "mutual": false,
#             "expertTags": null,
#             "experts": null,
#             "djStatus": 0,
#             "vipType": 0,
#             "remarkName": null,
#             "authenticationTypes": 0,
#             "avatarDetail": null,
#             "avatarImgIdStr": "109951163250233892",
#             "backgroundImgIdStr": "109951162868126486",
#             "anchor": false,
#             "avatarImgId_str": "109951163250233892"
#          },
#          {
#             "defaultAvatar": false,
#             "province": 340000,
#             "authStatus": 0,
#             "followed": false,
#             "avatarUrl": "http://p1.music.126.net/eT9YERMFQNnJNS5n5luN1Q==/109951164906682042.jpg",
#             "accountStatus": 0,
#             "gender": 1,
#             "city": 340100,
#             "birthday": -2209017600000,
#             "userId": 3295445735,
#             "userType": 0,
#             "nickname": "盼期待等",
#             "signature": "",
#             "description": "",
#             "detailDescription": "",
#             "avatarImgId": 109951164906682050,
#             "backgroundImgId": 109951165526602690,
#             "backgroundUrl": "http://p1.music.126.net/ZiwBGSaxdh9IJU-HctpSVA==/109951165526602691.jpg",
#             "authority": 0,
#             "mutual": false,
#             "expertTags": null,
#             "experts": null,
#             "djStatus": 0,
#             "vipType": 0,
#             "remarkName": null,
#             "authenticationTypes": 0,
#             "avatarDetail": null,
#             "avatarImgIdStr": "109951164906682042",
#             "backgroundImgIdStr": "109951165526602691",
#             "anchor": false,
#             "avatarImgId_str": "109951164906682042"
#          },
#          {
#             "defaultAvatar": false,
#             "province": 330000,
#             "authStatus": 0,
#             "followed": false,
#             "avatarUrl": "http://p1.music.126.net/8u3o5wnKUTH1eexT0wBWgQ==/18501482162277502.jpg",
#             "accountStatus": 0,
#             "gender": 2,
#             "city": 330400,
#             "birthday": -2209017600000,
#             "userId": 426049574,
#             "userType": 0,
#             "nickname": "Yuniskii",
#             "signature": "",
#             "description": "",
#             "detailDescription": "",
#             "avatarImgId": 18501482162277504,
#             "backgroundImgId": 2002210674180198,
#             "backgroundUrl": "http://p1.music.126.net/i0qi6mibX8gq2SaLF1bYbA==/2002210674180198.jpg",
#             "authority": 0,
#             "mutual": false,
#             "expertTags": null,
#             "experts": null,
#             "djStatus": 0,
#             "vipType": 11,
#             "remarkName": null,
#             "authenticationTypes": 0,
#             "avatarDetail": null,
#             "avatarImgIdStr": "18501482162277502",
#             "backgroundImgIdStr": "2002210674180198",
#             "anchor": false,
#             "avatarImgId_str": "18501482162277502"
#          },
#          {
#             "defaultAvatar": false,
#             "province": 620000,
#             "authStatus": 0,
#             "followed": false,
#             "avatarUrl": "http://p1.music.126.net/cxR9h7FrURzRP6c6qGdv6Q==/109951163131978404.jpg",
#             "accountStatus": 0,
#             "gender": 1,
#             "city": 620100,
#             "birthday": -2209017600000,
#             "userId": 1361867123,
#             "userType": 0,
#             "nickname": "M-iron",
#             "signature": "",
#             "description": "",
#             "detailDescription": "",
#             "avatarImgId": 109951163131978400,
#             "backgroundImgId": 109951162868126480,
#             "backgroundUrl": "http://p1.music.126.net/_f8R60U9mZ42sSNvdPn2sQ==/109951162868126486.jpg",
#             "authority": 0,
#             "mutual": false,
#             "expertTags": null,
#             "experts": null,
#             "djStatus": 0,
#             "vipType": 10,
#             "remarkName": null,
#             "authenticationTypes": 0,
#             "avatarDetail": null,
#             "avatarImgIdStr": "109951163131978404",
#             "backgroundImgIdStr": "109951162868126486",
#             "anchor": false,
#             "avatarImgId_str": "109951163131978404"
#          },
#          {
#             "defaultAvatar": false,
#             "province": 110000,
#             "authStatus": 0,
#             "followed": false,
#             "avatarUrl": "http://p1.music.126.net/N0T4i0-FLP1e4Mx6nww-wQ==/109951165572627342.jpg",
#             "accountStatus": 0,
#             "gender": 0,
#             "city": 110101,
#             "birthday": -2209017600000,
#             "userId": 3385916664,
#             "userType": 0,
#             "nickname": "AKA可ll",
#             "signature": "",
#             "description": "",
#             "detailDescription": "",
#             "avatarImgId": 109951165572627340,
#             "backgroundImgId": 109951165505942690,
#             "backgroundUrl": "http://p1.music.126.net/J3Td-tGiEV_yUB9bBOSFew==/109951165505942692.jpg",
#             "authority": 0,
#             "mutual": false,
#             "expertTags": null,
#             "experts": null,
#             "djStatus": 0,
#             "vipType": 11,
#             "remarkName": null,
#             "authenticationTypes": 0,
#             "avatarDetail": null,
#             "avatarImgIdStr": "109951165572627342",
#             "backgroundImgIdStr": "109951165505942692",
#             "anchor": false,
#             "avatarImgId_str": "109951165572627342"
#          },
#          {
#             "defaultAvatar": true,
#             "province": 440000,
#             "authStatus": 0,
#             "followed": false,
#             "avatarUrl": "http://p1.music.126.net/RLeBJe4D1ZzUtltxfoKDMg==/109951163250239066.jpg",
#             "accountStatus": 0,
#             "gender": 0,
#             "city": 440300,
#             "birthday": -2209017600000,
#             "userId": 1798221606,
#             "userType": 0,
#             "nickname": "夏日悠悠san",
#             "signature": "",
#             "description": "",
#             "detailDescription": "",
#             "avatarImgId": 109951163250239070,
#             "backgroundImgId": 109951162868126480,
#             "backgroundUrl": "http://p1.music.126.net/_f8R60U9mZ42sSNvdPn2sQ==/109951162868126486.jpg",
#             "authority": 0,
#             "mutual": false,
#             "expertTags": null,
#             "experts": null,
#             "djStatus": 0,
#             "vipType": 0,
#             "remarkName": null,
#             "authenticationTypes": 0,
#             "avatarDetail": null,
#             "avatarImgIdStr": "109951163250239066",
#             "backgroundImgIdStr": "109951162868126486",
#             "anchor": false,
#             "avatarImgId_str": "109951163250239066"
#          },
#          {
#             "defaultAvatar": false,
#             "province": 110000,
#             "authStatus": 0,
#             "followed": false,
#             "avatarUrl": "http://p1.music.126.net/CGBph23jmztPtVGP1QM5Zw==/109951163714610699.jpg",
#             "accountStatus": 0,
#             "gender": 1,
#             "city": 110101,
#             "birthday": -2209017600000,
#             "userId": 55419424,
#             "userType": 0,
#             "nickname": "来此只为你啦",
#             "signature": "●﹏●",
#             "description": "",
#             "detailDescription": "",
#             "avatarImgId": 109951163714610700,
#             "backgroundImgId": 2002210674180202,
#             "backgroundUrl": "http://p1.music.126.net/pmHS4fcQtcNEGewNb5HRhg==/2002210674180202.jpg",
#             "authority": 0,
#             "mutual": false,
#             "expertTags": null,
#             "experts": null,
#             "djStatus": 0,
#             "vipType": 0,
#             "remarkName": null,
#             "authenticationTypes": 0,
#             "avatarDetail": null,
#             "avatarImgIdStr": "109951163714610699",
#             "backgroundImgIdStr": "2002210674180202",
#             "anchor": false,
#             "avatarImgId_str": "109951163714610699"
#          }
#       ],
#       "subscribed": false,
#       "creator": {
#          "defaultAvatar": false,
#          "province": 110000,
#          "authStatus": 1,
#          "followed": false,
#          "avatarUrl": "http://p1.music.126.net/KxePid7qTvt6V2iYVy-rYQ==/109951165050882728.jpg",
#          "accountStatus": 0,
#          "gender": 1,
#          "city": 110101,
#          "birthday": -2209017600000,
#          "userId": 1,
#          "userType": 2,
#          "nickname": "网易云音乐",
#          "signature": "网易云音乐是8亿人都在使用的音乐平台，致力于帮助音乐爱好者发现音乐惊喜，帮助音乐人实现梦想。 \n2019年8月31日起，将不再提供实时在线人工服务。您可以优先通过自助方式解决问题，如仍需求助，可在相关页面留下您的问题，后续会有人工为您解答，辛苦您耐心等待，给您带来的不便敬请谅解。 如果仍然不能解决您的问题，可以邮件我们： 用户：ncm5990@163.com 音乐人：yyr599@163.com",
#          "description": "网易云音乐官方账号",
#          "detailDescription": "网易云音乐官方账号",
#          "avatarImgId": 109951165050882720,
#          "backgroundImgId": 2002210674180202,
#          "backgroundUrl": "http://p1.music.126.net/pmHS4fcQtcNEGewNb5HRhg==/2002210674180202.jpg",
#          "authority": 3,
#          "mutual": false,
#          "expertTags": null,
#          "experts": null,
#          "djStatus": 10,
#          "vipType": 11,
#          "remarkName": null,
#          "authenticationTypes": 4098,
#          "avatarDetail": {
#             "userType": 2,
#             "identityLevel": 1,
#             "identityIconUrl": "https://p5.music.126.net/obj/wo3DlcOGw6DClTvDisK1/4788940880/1a1f/68f5/b59a/b444b81b88567108ba88194fa29144f5.png"
#          },
#          "avatarImgIdStr": "109951165050882728",
#          "backgroundImgIdStr": "2002210674180202",
#          "anchor": true,
#          "avatarImgId_str": "109951165050882728"
#       },
#       "tracks": [
#          {
#             "name": "圈住你",
#             "id": 1372552573,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 30616590,
#                   "name": "一口甜",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [],
#             "pop": 100,
#             "st": 0,
#             "rt": "",
#             "fee": 8,
#             "v": 72,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 79854762,
#                "name": "圈住你",
#                "picUrl": "http://p3.music.126.net/Y05iUqwPp1IBwCj291_Ulg==/109951164156398679.jpg",
#                "tns": [],
#                "pic_str": "109951164156398679",
#                "pic": 109951164156398670
#             },
#             "dt": 178208,
#             "h": {
#                "br": 320000,
#                "fid": 0,
#                "size": 7130925,
#                "vd": -52433
#             },
#             "m": {
#                "br": 192000,
#                "fid": 0,
#                "size": 4278573,
#                "vd": -49861
#             },
#             "l": {
#                "br": 128000,
#                "fid": 0,
#                "size": 2852397,
#                "vd": -48176
#             },
#             "a": null,
#             "cd": "01",
#             "no": 1,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 0,
#             "s_id": 0,
#             "mark": 0,
#             "originCoverType": 1,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 1372818,
#             "mv": 0,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "name": "投己所好",
#             "id": 1371167139,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 4755,
#                   "name": "品冠",
#                   "tns": [],
#                   "alias": []
#                },
#                {
#                   "id": 13058503,
#                   "name": "尤长靖",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [],
#             "pop": 100,
#             "st": 0,
#             "rt": "",
#             "fee": 1,
#             "v": 6,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 80343462,
#                "name": "幸福指南编辑部",
#                "picUrl": "http://p4.music.126.net/hhQ5qi79t4iy5Bfx_MoVjw==/109951164207218956.jpg",
#                "tns": [],
#                "pic_str": "109951164207218956",
#                "pic": 109951164207218960
#             },
#             "dt": 193846,
#             "h": {
#                "br": 320000,
#                "fid": 0,
#                "size": 7755885,
#                "vd": -56595
#             },
#             "m": {
#                "br": 192000,
#                "fid": 0,
#                "size": 4653549,
#                "vd": -53993
#             },
#             "l": {
#                "br": 128000,
#                "fid": 0,
#                "size": 3102381,
#                "vd": -52325
#             },
#             "a": null,
#             "cd": "01",
#             "no": 5,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 1,
#             "s_id": 0,
#             "mark": 8192,
#             "originCoverType": 0,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 22036,
#             "mv": 0,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 1560268800000,
#             "alg": "alg_featured"
#          },
#          {
#             "name": "春风十里 (Live)",
#             "id": 1358935915,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 1195028,
#                   "name": "鹿先森乐队",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [],
#             "pop": 100,
#             "st": 0,
#             "rt": "",
#             "fee": 1,
#             "v": 5,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 78519791,
#                "name": "鹿先森乐队“华年”北京工体演唱会Live专辑",
#                "picUrl": "http://p4.music.126.net/FbsY3VujBzwe4wuEHlXtQA==/109951164000960267.jpg",
#                "tns": [],
#                "pic_str": "109951164000960267",
#                "pic": 109951164000960270
#             },
#             "dt": 398412,
#             "h": {
#                "br": 320000,
#                "fid": 0,
#                "size": 15938917,
#                "vd": -7000
#             },
#             "m": {
#                "br": 192000,
#                "fid": 0,
#                "size": 9563368,
#                "vd": -4300
#             },
#             "l": {
#                "br": 128000,
#                "fid": 0,
#                "size": 6375593,
#                "vd": -2700
#             },
#             "a": null,
#             "cd": "01",
#             "no": 10,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 1,
#             "s_id": 0,
#             "mark": 64,
#             "originCoverType": 0,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 1400821,
#             "mv": 0,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 1555344000000,
#             "alg": "alg_featured"
#          },
#          {
#             "name": "粉色星球",
#             "id": 1445556953,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 34375061,
#                   "name": "Youngior",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [],
#             "pop": 100,
#             "st": 0,
#             "rt": "",
#             "fee": 8,
#             "v": 14,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 88938751,
#                "name": "粉色星球",
#                "picUrl": "http://p3.music.126.net/NwZ--QgLDbipDwMVYxDYeQ==/109951164960533856.jpg",
#                "tns": [],
#                "pic_str": "109951164960533856",
#                "pic": 109951164960533860
#             },
#             "dt": 196000,
#             "h": {
#                "br": 320002,
#                "fid": 0,
#                "size": 7843048,
#                "vd": -70290
#             },
#             "m": {
#                "br": 192002,
#                "fid": 0,
#                "size": 4705846,
#                "vd": -67801
#             },
#             "l": {
#                "br": 128002,
#                "fid": 0,
#                "size": 3137245,
#                "vd": -66365
#             },
#             "a": null,
#             "cd": "01",
#             "no": 1,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 0,
#             "s_id": 0,
#             "mark": 64,
#             "originCoverType": 1,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 0,
#             "mv": 0,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 0,
#             "alg": "alg_featured"
#          },
#          {
#             "name": "大天蓬 (弹唱片段)",
#             "id": 1486086007,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 35233948,
#                   "name": "璐爷",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [],
#             "pop": 100,
#             "st": 0,
#             "rt": "",
#             "fee": 8,
#             "v": 5,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 96173575,
#                "name": "大天蓬 (抖音版)",
#                "picUrl": "http://p3.music.126.net/rn6L_xf1tlVAyHOz95mmMQ==/109951165354012465.jpg",
#                "tns": [],
#                "pic_str": "109951165354012465",
#                "pic": 109951165354012460
#             },
#             "dt": 43025,
#             "h": {
#                "br": 320008,
#                "fid": 0,
#                "size": 1724125,
#                "vd": -38685
#             },
#             "m": {
#                "br": 192009,
#                "fid": 0,
#                "size": 1034493,
#                "vd": -36007
#             },
#             "l": {
#                "br": 128008,
#                "fid": 0,
#                "size": 689676,
#                "vd": -34089
#             },
#             "a": null,
#             "cd": "01",
#             "no": 2,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 1,
#             "s_id": 0,
#             "mark": 0,
#             "originCoverType": 0,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 1416673,
#             "mv": 0,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 1602259200000,
#             "alg": "alg_tag_based"
#          },
#          {
#             "name": "昨日青空",
#             "id": 1293951677,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 13058503,
#                   "name": "尤长靖",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [
#                "电影《昨日青空》同名青春主题曲"
#             ],
#             "pop": 100,
#             "st": 0,
#             "rt": null,
#             "fee": 0,
#             "v": 2,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 71855745,
#                "name": "昨日青空",
#                "picUrl": "http://p3.music.126.net/5BLwaGxULPLXWhhnIzD2CQ==/109951163413015911.jpg",
#                "tns": [],
#                "pic_str": "109951163413015911",
#                "pic": 109951163413015900
#             },
#             "dt": 279883,
#             "h": {
#                "br": 320000,
#                "fid": 0,
#                "size": 11198215,
#                "vd": -21800
#             },
#             "m": {
#                "br": 192000,
#                "fid": 0,
#                "size": 6718946,
#                "vd": -19200
#             },
#             "l": {
#                "br": 128000,
#                "fid": 0,
#                "size": 4479312,
#                "vd": -17600
#             },
#             "a": null,
#             "cd": "01",
#             "no": 1,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 0,
#             "s_id": 0,
#             "mark": 0,
#             "originCoverType": 1,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 415022,
#             "mv": 10738068,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 1531929600007,
#             "alg": "alg_tag_based"
#          },
#          {
#             "name": "思念是一种病",
#             "id": 185700,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 6453,
#                   "name": "张震岳",
#                   "tns": [],
#                   "alias": []
#                },
#                {
#                   "id": 7214,
#                   "name": "蔡健雅",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [],
#             "pop": 100,
#             "st": 0,
#             "rt": "600902000007994111",
#             "fee": 8,
#             "v": 42,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 18878,
#                "name": "OK",
#                "picUrl": "http://p4.music.126.net/N61oLy0iLfEkZTHD2j87iA==/18693896697392706.jpg",
#                "tns": [],
#                "pic_str": "18693896697392706",
#                "pic": 18693896697392704
#             },
#             "dt": 259000,
#             "h": {
#                "br": 320000,
#                "fid": 0,
#                "size": 10390508,
#                "vd": -12500
#             },
#             "m": {
#                "br": 192000,
#                "fid": 0,
#                "size": 6234322,
#                "vd": -10000
#             },
#             "l": {
#                "br": 128000,
#                "fid": 0,
#                "size": 4156229,
#                "vd": -8800
#             },
#             "a": null,
#             "cd": "1",
#             "no": 1,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 0,
#             "s_id": 0,
#             "mark": 1125899906851328,
#             "originCoverType": 2,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 684010,
#             "mv": 10930371,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 1183219200000,
#             "alg": "alg_tag_based"
#          },
#          {
#             "name": "弦外音",
#             "id": 1501704986,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 12205486,
#                   "name": "黄钧泽",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [],
#             "pop": 100,
#             "st": 0,
#             "rt": "",
#             "fee": 8,
#             "v": 3,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 99325073,
#                "name": "弦外音",
#                "picUrl": "http://p4.music.126.net/gHaduNbH7cvXi4HkBcrwXw==/109951165529521302.jpg",
#                "tns": [],
#                "pic_str": "109951165529521302",
#                "pic": 109951165529521300
#             },
#             "dt": 221250,
#             "h": {
#                "br": 320000,
#                "fid": 0,
#                "size": 8852205,
#                "vd": -54465
#             },
#             "m": {
#                "br": 192000,
#                "fid": 0,
#                "size": 5311341,
#                "vd": -51876
#             },
#             "l": {
#                "br": 128000,
#                "fid": 0,
#                "size": 3540909,
#                "vd": -50329
#             },
#             "a": null,
#             "cd": "01",
#             "no": 1,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 1,
#             "s_id": 0,
#             "mark": 0,
#             "originCoverType": 0,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 1416842,
#             "mv": 0,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 1607616000000,
#             "alg": "official_by_force_insert"
#          },
#          {
#             "name": "想想念念",
#             "id": 1382592790,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 13006131,
#                   "name": "FAFA",
#                   "tns": [],
#                   "alias": []
#                },
#                {
#                   "id": 12271005,
#                   "name": "雪二",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [],
#             "pop": 100,
#             "st": 0,
#             "rt": "",
#             "fee": 8,
#             "v": 6,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 80815986,
#                "name": "想想念念",
#                "picUrl": "http://p4.music.126.net/141huUN4P3Vf-eeEO6-Oqw==/109951164271818440.jpg",
#                "tns": [],
#                "pic_str": "109951164271818440",
#                "pic": 109951164271818430
#             },
#             "dt": 181404,
#             "h": {
#                "br": 320000,
#                "fid": 0,
#                "size": 7258605,
#                "vd": -58028
#             },
#             "m": {
#                "br": 192000,
#                "fid": 0,
#                "size": 4355181,
#                "vd": -55431
#             },
#             "l": {
#                "br": 128000,
#                "fid": 0,
#                "size": 2903469,
#                "vd": -53719
#             },
#             "a": null,
#             "cd": "01",
#             "no": 1,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 0,
#             "s_id": 0,
#             "mark": 0,
#             "originCoverType": 1,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 1372818,
#             "mv": 0,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "name": "光",
#             "id": 30431364,
#             "pst": 0,
#             "t": 0,
#             "ar": [
#                {
#                   "id": 1007170,
#                   "name": "陈粒",
#                   "tns": [],
#                   "alias": []
#                }
#             ],
#             "alia": [],
#             "pop": 100,
#             "st": 0,
#             "rt": null,
#             "fee": 8,
#             "v": 22,
#             "crbt": null,
#             "cf": "",
#             "al": {
#                "id": 3098832,
#                "name": "如也",
#                "picUrl": "http://p4.music.126.net/VuJFMbXzpAProbJPoXLv7g==/7721870161993398.jpg",
#                "tns": [],
#                "pic": 7721870161993398
#             },
#             "dt": 141000,
#             "h": {
#                "br": 320000,
#                "fid": 0,
#                "size": 5649806,
#                "vd": -17600
#             },
#             "m": {
#                "br": 192000,
#                "fid": 0,
#                "size": 3389901,
#                "vd": -14900
#             },
#             "l": {
#                "br": 128000,
#                "fid": 0,
#                "size": 2259948,
#                "vd": -13200
#             },
#             "a": null,
#             "cd": "1",
#             "no": 5,
#             "rtUrl": null,
#             "ftype": 0,
#             "rtUrls": [],
#             "djId": 0,
#             "copyright": 2,
#             "s_id": 0,
#             "mark": 0,
#             "originCoverType": 1,
#             "originSongSimpleData": null,
#             "single": 0,
#             "noCopyrightRcmd": null,
#             "mst": 9,
#             "cp": 753020,
#             "mv": 0,
#             "rtype": 0,
#             "rurl": null,
#             "publishTime": 1422806400007,
#             "alg": "alg_tag_based"
#          }
#       ],
#       "videoIds": null,
#       "videos": null,
#       "trackIds": [
#          {
#             "id": 1372552573,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1371167139,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_featured"
#          },
#          {
#             "id": 1358935915,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_featured"
#          },
#          {
#             "id": 1445556953,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_featured"
#          },
#          {
#             "id": 1486086007,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1293951677,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 185700,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1501704986,
#             "v": -10000,
#             "at": 0,
#             "alg": "official_by_force_insert"
#          },
#          {
#             "id": 1382592790,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 30431364,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 450853439,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 492390949,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1363883359,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 254485,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 461080452,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 176053,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1430287528,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1488288505,
#             "v": -10000,
#             "at": 0,
#             "alg": "official_by_force_insert"
#          },
#          {
#             "id": 470057375,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1335580481,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 31654343,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 293948,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 254359,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1321631043,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1382592787,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1408220694,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 489302317,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1344814341,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 351271,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1357816405,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 446627373,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 502043537,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 569200210,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 1374086946,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          },
#          {
#             "id": 414706021,
#             "v": -10000,
#             "at": 0,
#             "alg": "alg_tag_based"
#          }
#       ],
#       "updateFrequency": "每日更新",
#       "backgroundCoverId": 109951164273689890,
#       "backgroundCoverUrl": "http://p2.music.126.net/OkY6SsqSHPwvv3yj7QVpOA==/109951164273689890.jpg",
#       "titleImage": 109951164389726900,
#       "titleImageUrl": "http://p2.music.126.net/8ll54Hd7mPeIKbYhItpqzw==/109951164389726899.jpg",
#       "englishTitle": "Chinese",
#       "opRecommend": false,
#       "description": "全都是耐听的华语好歌\n这里是你的专属华语日推\n收藏订阅，歌荒，不存在的事",
#       "userId": 1,
#       "createTime": 1559735469152,
#       "highQuality": false,
#       "adType": 0,
#       "trackNumberUpdateTime": 1609279200000,
#       "ordered": false,
#       "tags": [
#          "华语"
#       ],
#       "subscribedCount": 3933265,
#       "specialType": 100,
#       "coverImgUrl": "http://p2.music.126.net/wTcIyvb9xPsNzZTJ7ettow==/109951164273697592.jpg",
#       "playCount": 537350080,
#       "updateTime": 1578549322912,
#       "newImported": false,
#       "trackCount": 35,
#       "commentThreadId": "A_PL_0_2829883282",
#       "privacy": 0,
#       "trackUpdateTime": 1609319398328,
#       "coverImgId": 109951164273697600,
#       "cloudTrackCount": 0,
#       "status": 0,
#       "name": "[华语私人订制] 最懂你的华语推荐 每日更新35首",
#       "id": 2829883282,
#       "shareCount": 23345,
#       "coverImgId_str": "109951164614300882",
#       "commentCount": 45053
#    },
#    "urls": null,
#    "privileges": [
#       {
#          "id": 1372552573,
#          "fee": 8,
#          "payed": 0,
#          "st": 0,
#          "pl": 128000,
#          "dl": 0,
#          "sp": 7,
#          "cp": 1,
#          "subp": 1,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 128000,
#          "toast": false,
#          "flag": 0,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       },
#       {
#          "id": 1371167139,
#          "fee": 1,
#          "payed": 0,
#          "st": 0,
#          "pl": 0,
#          "dl": 0,
#          "sp": 0,
#          "cp": 0,
#          "subp": 0,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 0,
#          "toast": false,
#          "flag": 1028,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       },
#       {
#          "id": 1358935915,
#          "fee": 1,
#          "payed": 0,
#          "st": 0,
#          "pl": 0,
#          "dl": 0,
#          "sp": 0,
#          "cp": 0,
#          "subp": 0,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 0,
#          "toast": false,
#          "flag": 1026,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       },
#       {
#          "id": 1445556953,
#          "fee": 8,
#          "payed": 0,
#          "st": 0,
#          "pl": 128000,
#          "dl": 0,
#          "sp": 7,
#          "cp": 1,
#          "subp": 1,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 128000,
#          "toast": false,
#          "flag": 66,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       },
#       {
#          "id": 1486086007,
#          "fee": 8,
#          "payed": 0,
#          "st": 0,
#          "pl": 128000,
#          "dl": 0,
#          "sp": 7,
#          "cp": 1,
#          "subp": 1,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 128000,
#          "toast": false,
#          "flag": 0,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       },
#       {
#          "id": 1293951677,
#          "fee": 0,
#          "payed": 0,
#          "st": 0,
#          "pl": 320000,
#          "dl": 999000,
#          "sp": 7,
#          "cp": 1,
#          "subp": 1,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 320000,
#          "toast": false,
#          "flag": 256,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       },
#       {
#          "id": 185700,
#          "fee": 8,
#          "payed": 0,
#          "st": 0,
#          "pl": 128000,
#          "dl": 0,
#          "sp": 7,
#          "cp": 1,
#          "subp": 1,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 128000,
#          "toast": false,
#          "flag": 68,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       },
#       {
#          "id": 1501704986,
#          "fee": 8,
#          "payed": 0,
#          "st": 0,
#          "pl": 128000,
#          "dl": 0,
#          "sp": 7,
#          "cp": 1,
#          "subp": 1,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 128000,
#          "toast": false,
#          "flag": 0,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       },
#       {
#          "id": 1382592790,
#          "fee": 8,
#          "payed": 0,
#          "st": 0,
#          "pl": 128000,
#          "dl": 0,
#          "sp": 7,
#          "cp": 1,
#          "subp": 1,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 128000,
#          "toast": false,
#          "flag": 0,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       },
#       {
#          "id": 30431364,
#          "fee": 8,
#          "payed": 0,
#          "st": 0,
#          "pl": 128000,
#          "dl": 0,
#          "sp": 7,
#          "cp": 1,
#          "subp": 1,
#          "cs": false,
#          "maxbr": 999000,
#          "fl": 128000,
#          "toast": false,
#          "flag": 0,
#          "preSell": false,
#          "playMaxbr": 999000,
#          "downloadMaxbr": 999000,
#          "freeTrialPrivilege": {
#             "resConsumable": false,
#             "userConsumable": false
#          },
#          "chargeInfoList": [
#             {
#                "rate": 128000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 0
#             },
#             {
#                "rate": 192000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 320000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             },
#             {
#                "rate": 999000,
#                "chargeUrl": null,
#                "chargeMessage": null,
#                "chargeType": 1
#             }
#          ]
#       }
#    ]
# }

# %%
filename = 'test_data.json'
with open(filename, 'w', encoding='utf-8') as fw:
    json.dump(data_dict, fw, ensure_ascii=False)

# %%
# 获取所有的歌曲id
track_ids = data_dict.get("playlist").get("trackIds")

# %%
print(len(track_ids))
# Out:
# 35

# %%
song_ids = []
for track in track_ids:
    song_id = track.get('id')
    song_ids.append(song_id)

# %%
# 歌单中所有歌曲的id
song_ids
# Out:
# [1372552573,
#  1371167139,
#  1358935915,
#  1445556953,
#  1486086007,
#  1293951677,
#  185700,
#  1501704986,
#  1382592790,
#  30431364,
#  450853439,
#  492390949,
#  1363883359,
#  254485,
#  461080452,
#  176053,
#  1430287528,
#  1488288505,
#  470057375,
#  1335580481,
#  31654343,
#  293948,
#  254359,
#  1321631043,
#  1382592787,
#  1408220694,
#  489302317,
#  1344814341,
#  351271,
#  1357816405,
#  446627373,
#  502043537,
#  569200210,
#  1374086946,
#  414706021]

# %%
# 歌单的标签列表
tags_list = data_dict.get("playlist").get("tags")

# %%
# 歌单名称
name = data_dict.get("playlist").get("name")

# %%
# 歌单订阅数量
subscribedCount = data_dict.get("playlist").get("subscribedCount")

# %%
# 歌单播放数量
playCount = data_dict.get("playlist").get("playCount")

# %%
playlist_info_dict = {
    "playlist_id": 2829883282,
    "song_ids":song_ids,
    "tags_list": tags_list,
    "name": name,
    "subscribedCount": subscribedCount,
    "playCount": playCount,
}

# %%
playlist_info_dict
# Out:
# {'playlist_id': 2829883282,
#  'song_ids': [1372552573,
#   1371167139,
#   1358935915,
#   1445556953,
#   1486086007,
#   1293951677,
#   185700,
#   1501704986,
#   1382592790,
#   30431364,
#   450853439,
#   492390949,
#   1363883359,
#   254485,
#   461080452,
#   176053,
#   1430287528,
#   1488288505,
#   470057375,
#   1335580481,
#   31654343,
#   293948,
#   254359,
#   1321631043,
#   1382592787,
#   1408220694,
#   489302317,
#   1344814341,
#   351271,
#   1357816405,
#   446627373,
#   502043537,
#   569200210,
#   1374086946,
#   414706021],
#  'tags_list': ['华语'],
#  'name': '[华语私人订制] 最懂你的华语推荐 每日更新35首',
#  'subscribedCount': 3933265,
#  'playCount': 537350080}

# %% [markdown]
# ## 热门评论

# %%
r = rq.get('https://autumnfish.cn/comment/hot?id=446508414&type=0')
data = r.text
print(data)
# Out:
# {"topComments":[],"hasMore":true,"hotComments":[{"user":{"locationInfo":null,"liveInfo":null,"anonym":0,"userId":307253184,"avatarDetail":null,"userType":0,"remarkName":null,"vipRights":{"associator":{"vipCode":100,"rights":true},"musicPackage":null,"redVipAnnualCount":-1,"redVipLevel":2},"nickname":"絕世愛戀","avatarUrl":"https://p3.music.126.net/SurZ4byoKhx9Zlt0Ir4S9w==/109951165538723123.jpg","authStatus":0,"expertTags":null,"experts":null,"vipType":11},"beReplied":[],"pendantData":null,"showFloorComment":null,"status":0,"commentId":1298657805,"content":"很喜欢这个平台\n没人嘲笑你的遭遇\n还有很多人爱你","time":1542116923486,"likedCount":4632,"expressionUrl":null,"commentLocationType":0,"parentCommentId":0,"decoration":null,"repliedMark":null,"liked":false},{"user":{"locationInfo":null,"liveInfo":null,"anonym":0,"userId":501841441,"avatarDetail":{"userType":4,"identityLevel":1,"identityIconUrl":"https://p5.music.126.net/obj/wo3DlcOGw6DClTvDisK1/4874132307/4499/f228/d867/da64b9725e125943ad4e14e4c72d0884.png"},"userType":4,"remarkName":null,"vipRights":{"associator":{"vipCode":100,"rights":true},"musicPackage":null,"redVipAnnualCount":1,"redVipLevel":6},"nickname":"川仓晴香","avatarUrl":"https://p3.music.126.net/a2R-tRDh10vrvFylog6OHQ==/109951165286000661.jpg","authStatus":1,"expertTags":null,"experts":null,"vipType":11},"beReplied":[],"pendantData":null,"showFloorComment":null,"status":0,"commentId":1304155780,"content":"我的心理医生对我说 你以为你想死 其实你是想被别人拯救","time":1542644999372,"likedCount":3849,"expressionUrl":null,"commentLocationType":0,"parentCommentId":0,"decoration":null,"repliedMark":null,"liked":false},{"user":{"locationInfo":null,"liveInfo":null,"anonym":0,"userId":320456408,"avatarDetail":null,"userType":0,"remarkName":null,"vipRights":null,"nickname":"-Inertia","avatarUrl":"https://p4.music.126.net/QzALY2oizyfJjFFXAJ8iGw==/109951165412958073.jpg","authStatus":0,"expertTags":null,"experts":null,"vipType":0},"beReplied":[],"pendantData":null,"showFloorComment":null,"status":0,"commentId":1302448210,"content":"你迷茫是因为你想要的太多了但你又不努力","time":1542492612202,"likedCount":2608,"expressionUrl":null,"commentLocationType":0,"parentCommentId":0,"decoration":null,"repliedMark":null,"liked":false},{"user":{"locationInfo":null,"liveInfo":null,"anonym":0,"userId":1870836131,"avatarDetail":null,"userType":0,"remarkName":null,"vipRights":null,"nickname":"不要小鬼了m","avatarUrl":"https://p3.music.126.net/JsK-HaQJTt_tbI_lQZlsxQ==/109951165261342830.jpg","authStatus":0,"expertTags":null,"experts":null,"vipType":0},"beReplied":[],"pendantData":null,"showFloorComment":null,"status":0,"commentId":3115314571,"content":"妲己一直喂纣王吃葡萄 因为在狐狸眼里葡萄是最好的","time":1578671449142,"likedCount":850,"expressionUrl":null,"commentLocationType":0,"parentCommentId":0,"decoration":{},"repliedMark":null,"liked":false},{"user":{"locationInfo":null,"liveInfo":null,"anonym":0,"userId":471423866,"avatarDetail":null,"userType":0,"remarkName":null,"vipRights":{"associator":{"vipCode":100,"rights":true},"musicPackage":null,"redVipAnnualCount":-1,"redVipLevel":1},"nickname":"毁除","avatarUrl":"https://p4.music.126.net/zpHe6RU7D0J_vKUanqPyow==/109951165557463148.jpg","authStatus":0,"expertTags":null,"experts":null,"vipType":11},"beReplied":[],"pendantData":null,"showFloorComment":null,"status":0,"commentId":1295998506,"content":"期待是什么 劝你省省力气","time":1541844513888,"likedCount":749,"expressionUrl":null,"commentLocationType":0,"parentCommentId":0,"decoration":null,"repliedMark":null,"liked":false},{"user":{"locationInfo":null,"liveInfo":null,"anonym":0,"userId":37858326,"avatarDetail":{"userType":4,"identityLevel":1,"identityIconUrl":"https://p5.music.126.net/obj/wo3DlcOGw6DClTvDisK1/4874132307/4499/f228/d867/da64b9725e125943ad4e14e4c72d0884.png"},"userType":4,"remarkName":null,"vipRights":null,"nickname":"MartinTungevaag","avatarUrl":"https://p3.music.126.net/DAHqPh6RCOxhLUmwDOf8mg==/109951164756960106.jpg","authStatus":1,"expertTags":null,"experts":null,"vipType":0},"beReplied":[],"pendantData":null,"showFloorComment": ...

# %%
json.loads(data)
# Out:
# {'topComments': [],
#  'hasMore': True,
#  'hotComments': [{'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 307253184,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': -1,
#      'redVipLevel': 2},
#     'nickname': '絕世愛戀',
#     'avatarUrl': 'https://p3.music.126.net/SurZ4byoKhx9Zlt0Ir4S9w==/109951165538723123.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1298657805,
#    'content': '很喜欢这个平台\n没人嘲笑你的遭遇\n还有很多人爱你',
#    'time': 1542116923486,
#    'likedCount': 4632,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 501841441,
#     'avatarDetail': {'userType': 4,
#      'identityLevel': 1,
#      'identityIconUrl': 'https://p5.music.126.net/obj/wo3DlcOGw6DClTvDisK1/4874132307/4499/f228/d867/da64b9725e125943ad4e14e4c72d0884.png'},
#     'userType': 4,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': 1,
#      'redVipLevel': 6},
#     'nickname': '川仓晴香',
#     'avatarUrl': 'https://p3.music.126.net/a2R-tRDh10vrvFylog6OHQ==/109951165286000661.jpg',
#     'authStatus': 1,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1304155780,
#    'content': '我的心理医生对我说 你以为你想死 其实你是想被别人拯救',
#    'time': 1542644999372,
#    'likedCount': 3849,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 320456408,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': '-Inertia',
#     'avatarUrl': 'https://p4.music.126.net/QzALY2oizyfJjFFXAJ8iGw==/109951165412958073.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1302448210,
#    'content': '你迷茫是因为你想要的太多了但你又不努力',
#    'time': 1542492612202,
#    'likedCount': 2608,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 1870836131,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': '不要小鬼了m',
#     'avatarUrl': 'https://p3.music.126.net/JsK-HaQJTt_tbI_lQZlsxQ==/109951165261342830.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3115314571,
#    'content': '妲己一直喂纣王吃葡萄 因为在狐狸眼里葡萄是最好的',
#    'time': 1578671449142,
#    'likedCount': 850,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 471423866,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': -1,
#      'redVipLevel': 1},
#     'nickname': '毁除',
#     'avatarUrl': 'https://p4.music.126.net/zpHe6RU7D0J_vKUanqPyow==/109951165557463148.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1295998506,
#    'content': '期待是什么 劝你省省力气',
#    'time': 1541844513888,
#    'likedCount': 749,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 37858326,
#     'avatarDetail': {'userType': 4,
#      'identityLevel': 1,
#      'identityIconUrl': 'https://p5.music.126.net/obj/wo3DlcOGw6DClTvDisK1/4874132307/4499/f228/d867/da64b9725e125943ad4e14e4c72d0884.png'},
#     'userType': 4,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': 'MartinTungevaag',
#     'avatarUrl': 'https://p3.music.126.net/DAHqPh6RCOxhLUmwDOf8mg==/109951164756960106.jpg',
#     'authStatus': 1,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 264128543,
#    'content': '已上船：GYVUS - Blue Sky  [钟情]',
#    'time': 1481528677479,
#    'likedCount': 564,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 545784698,
#     'avatarDetail': {'userType': 4,
#      'identityLevel': 1,
#      'identityIconUrl': 'https://p5.music.126.net/obj/wo3DlcOGw6DClTvDisK1/4874132307/4499/f228/d867/da64b9725e125943ad4e14e4c72d0884.png'},
#     'userType': 4,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': 'Southliany',
#     'avatarUrl': 'https://p3.music.126.net/Bf5Ugl3Wdv0GfPohAeVFZg==/109951165081995947.jpg',
#     'authStatus': 1,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1340789633,
#    'content': '沉默总比痛哭好吧。',
#    'time': 1546051403098,
#    'likedCount': 507,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 516321657,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': '我可爱都是假的我连雀斑都是画的',
#     'avatarUrl': 'https://p3.music.126.net/7b-S55ZfAHhaHzoLDoL7Tw==/109951164207445647.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1335482416,
#    'content': '世界会不会好不重要  你要变好 \u200b\u200b\u200b',
#    'time': 1545551038017,
#    'likedCount': 366,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 351014186,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': -1,
#      'redVipLevel': 5},
#     'nickname': '郭沫若雷诺十二月',
#     'avatarUrl': 'https://p4.music.126.net/CvSNBbsI-r-cGn0wT3cgCA==/109951163578021736.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [{'user': {'locationInfo': None,
#       'liveInfo': None,
#       'anonym': 0,
#       'userId': 501841441,
#       'avatarDetail': None,
#       'userType': 4,
#       'remarkName': None,
#       'vipRights': None,
#       'nickname': '川仓晴香',
#       'avatarUrl': 'https://p3.music.126.net/a2R-tRDh10vrvFylog6OHQ==/109951165286000661.jpg',
#       'authStatus': 1,
#       'expertTags': None,
#       'experts': None,
#       'vipType': 11},
#      'beRepliedCommentId': 1304155780,
#      'content': '我的心理医生对我说 你以为你想死 其实你是想被别人拯救',
#      'status': 0,
#      'expressionUrl': None}],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1345207822,
#    'content': '很多时候外人比自己看得更透',
#    'time': 1546427925616,
#    'likedCount': 328,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 1304155780,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 284093586,
#     'avatarDetail': {'userType': 4,
#      'identityLevel': 1,
#      'identityIconUrl': 'https://p5.music.126.net/obj/wo3DlcOGw6DClTvDisK1/4874132307/4499/f228/d867/da64b9725e125943ad4e14e4c72d0884.png'},
#     'userType': 4,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': 1,
#      'redVipLevel': 6},
#     'nickname': '胡溪溪2happy',
#     'avatarUrl': 'https://p3.music.126.net/5mQGzG--ErN0oV_04t0rCQ==/109951163797123204.jpg',
#     'authStatus': 1,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1255689388,
#    'content': '用这首给喜欢的人写了一首歌 歌很烂 喜欢的人也没有追到[皱眉]',
#    'time': 1537884092399,
#    'likedCount': 317,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 1691360751,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': -1,
#      'redVipLevel': 2},
#     'nickname': '鲸纵',
#     'avatarUrl': 'https://p3.music.126.net/Qyrm901HoVNbEkqwG-MJfQ==/109951165509355526.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3161890762,
#    'content': '在月球上会发生地震    这种现象被称为月震（Moonquakes） 而在地球的人们却浑然不知    就好像我在你身边不断无法抑制的心动而你却毫无发觉',
#    'time': 1582100736591,
#    'likedCount': 292,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 373651208,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': 'lmsrry',
#     'avatarUrl': 'https://p3.music.126.net/65raY07XjUerLbrhse_C6A==/109951164614046859.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1471624200,
#    'content': '先笑一下 说不定你所期待的事等等就来了',
#    'time': 1556582586519,
#    'likedCount': 225,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 1518992772,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': -1,
#      'redVipLevel': 1},
#     'nickname': '这次要顺顺利利',
#     'avatarUrl': 'https://p4.music.126.net/QKIf15ooGH0eW8Os9crTtg==/109951165314507737.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [{'user': {'locationInfo': None,
#       'liveInfo': None,
#       'anonym': 0,
#       'userId': 307253184,
#       'avatarDetail': None,
#       'userType': 0,
#       'remarkName': None,
#       'vipRights': None,
#       'nickname': '絕世愛戀',
#       'avatarUrl': 'https://p3.music.126.net/SurZ4byoKhx9Zlt0Ir4S9w==/109951165538723123.jpg',
#       'authStatus': 0,
#       'expertTags': None,
#       'experts': None,
#       'vipType': 11},
#      'beRepliedCommentId': 1298657805,
#      'content': '很喜欢这个平台\n没人嘲笑你的遭遇\n还有很多人爱你',
#      'status': 0,
#      'expressionUrl': None}],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1344110410,
#    'content': '你一定很爱这个平台',
#    'time': 1546327907543,
#    'likedCount': 213,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 1298657805,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 1420587436,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': '慕帝辛-',
#     'avatarUrl': 'https://p3.music.126.net/Y33XhjamesAfGRubWUZPiQ==/109951164910996933.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [{'user': {'locationInfo': None,
#       'liveInfo': None,
#       'anonym': 0,
#       'userId': 1870836131,
#       'avatarDetail': None,
#       'userType': 0,
#       'remarkName': None,
#       'vipRights': None,
#       'nickname': '不要小鬼了m',
#       'avatarUrl': 'https://p4.music.126.net/JsK-HaQJTt_tbI_lQZlsxQ==/109951165261342830.jpg',
#       'authStatus': 0,
#       'expertTags': None,
#       'experts': None,
#       'vipType': 0},
#      'beRepliedCommentId': 3115314571,
#      'content': '妲己一直喂纣王吃葡萄 因为在狐狸眼里葡萄是最好的',
#      'status': 0,
#      'expressionUrl': None}],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3267411975,
#    'content': '爱妃给寡人喂什么，寡人就吃什么，只要是你递给寡人的，哪怕是毒酒，寡人也甘愿饮下',
#    'time': 1587045495607,
#    'likedCount': 192,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 3115314571,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': '同城',
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 353417103,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': '暴躁喵仙女',
#     'avatarUrl': 'https://p3.music.126.net/bM8-67EWS9fChBal7XKNHA==/109951165501626440.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [{'user': {'locationInfo': None,
#       'liveInfo': None,
#       'anonym': 0,
#       'userId': 417270443,
#       'avatarDetail': None,
#       'userType': 0,
#       'remarkName': None,
#       'vipRights': None,
#       'nickname': '缡人心上秋',
#       'avatarUrl': 'https://p4.music.126.net/8dC2XjxaYA8lIYFzeBdDIQ==/109951164980562518.jpg',
#       'authStatus': 0,
#       'expertTags': None,
#       'experts': None,
#       'vipType': 11},
#      'beRepliedCommentId': 3309100476,
#      'content': '“我喜欢你”加上一个字，哪个最扎心呢...',
#      'status': 0,
#      'expressionUrl': None}],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3309845254,
#    'content': '我喜欢 上你',
#    'time': 1589481013392,
#    'likedCount': 183,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 3309100476,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 447008736,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': '叫我嘉豪就行',
#     'avatarUrl': 'https://p4.music.126.net/ODI45OzJcvX1wiQKt2AI1A==/109951165059176123.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3471589912,
#    'content': '突然乌云风暴 覆盖了所有通道',
#    'time': 1601976027842,
#    'likedCount': 172,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 418891814,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': -1,
#      'redVipLevel': 5},
#     'nickname': '灰子猪也',
#     'avatarUrl': 'https://p4.music.126.net/YaI1T6gC0_yA_vK6zYVIpg==/18955580463012663.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [{'user': {'locationInfo': None,
#       'liveInfo': None,
#       'anonym': 0,
#       'userId': 417270443,
#       'avatarDetail': None,
#       'userType': 0,
#       'remarkName': None,
#       'vipRights': None,
#       'nickname': '缡人心上秋',
#       'avatarUrl': 'https://p4.music.126.net/8dC2XjxaYA8lIYFzeBdDIQ==/109951164980562518.jpg',
#       'authStatus': 0,
#       'expertTags': None,
#       'experts': None,
#       'vipType': 11},
#      'beRepliedCommentId': 3309100476,
#      'content': '“我喜欢你”加上一个字，哪个最扎心呢...',
#      'status': 0,
#      'expressionUrl': None}],
#    'pendantData': {'id': 24000,
#     'imageUrl': 'http://p1.music.126.net/EJMMnKyBo0bsmVhggxGQDw==/109951164219710144.jpg'},
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3321200822,
#    'content': '我喜欢你爸',
#    'time': 1590289587922,
#    'likedCount': 168,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 3309100476,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 344080654,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': 1,
#      'redVipLevel': 6},
#     'nickname': 'ZycMatata',
#     'avatarUrl': 'https://p3.music.126.net/EekFhnDAAYQxUr5U9Uaqkw==/109951165236130552.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [{'user': {'locationInfo': None,
#       'liveInfo': None,
#       'anonym': 0,
#       'userId': 307253184,
#       'avatarDetail': None,
#       'userType': 0,
#       'remarkName': None,
#       'vipRights': None,
#       'nickname': '絕世愛戀',
#       'avatarUrl': 'https://p3.music.126.net/SurZ4byoKhx9Zlt0Ir4S9w==/109951165538723123.jpg',
#       'authStatus': 0,
#       'expertTags': None,
#       'experts': None,
#       'vipType': 11},
#      'beRepliedCommentId': 1298657805,
#      'content': '很喜欢这个平台\n没人嘲笑你的遭遇\n还有很多人爱你',
#      'status': 0,
#      'expressionUrl': None}],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 1359188076,
#    'content': '不管你现实生活中有怎样的遭遇 但是在这里我是先给你点的赞然后点的红心 你好有品位的人',
#    'time': 1547629399152,
#    'likedCount': 165,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 1298657805,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 1387001205,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': None,
#     'nickname': 'lonelydolI',
#     'avatarUrl': 'https://p3.music.126.net/l8iyzgOciO1AZDH9Z9Y6kw==/109951165567859295.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 0},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3379280361,
#    'content': '靠 居然有这么好听的jazz hiphop',
#    'time': 1594863384623,
#    'likedCount': 163,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'anonym': 0,
#     'userId': 417270443,
#     'avatarDetail': None,
#     'userType': 0,
#     'remarkName': None,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': -1,
#      'redVipLevel': 5},
#     'nickname': '缡人心上秋',
#     'avatarUrl': 'https://p3.music.126.net/8dC2XjxaYA8lIYFzeBdDIQ==/109951164980562518.jpg',
#     'authStatus': 0,
#     'expertTags': None,
#     'experts': None,
#     'vipType': 11},
#    'beReplied': [],
#    'pendantData': {'id': 59203,
#     'imageUrl': 'http://p1.music.126.net/P40Tut6mJHNKA2GBb-AZoA==/109951164881213901.jpg'},
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3309100476,
#    'content': '“我喜欢你”加上一个字，哪个最扎心呢...',
#    'time': 1589445336727,
#    'likedCount': 163,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False}],
#  'total': 99,
#  'code': 200}

# %% [markdown]
# ## 歌单搜索

# %%
r = rq.get('https://autumnfish.cn/search?keywords=恐怖&limit=30&type=1000&offset=300')
data = r.text
print(data)
# Out:
# {"result":{"playlists":[{"id":2281417142,"name":"恐怖","coverImgUrl":"https://p2.music.126.net/o_kM3LCuiIqHSJj-uuqNtw==/109951164405513949.jpg","creator":{"nickname":"salomjon88","userId":1369714741,"userType":0,"authStatus":0,"expertTags":null,"experts":null},"subscribed":false,"trackCount":19,"userId":1369714741,"playCount":15,"bookCount":0,"specialType":0,"officialTags":null,"description":"勇敢点儿来听","highQuality":false,"track":{"name":"幽闭恐怖症的房间","id":349705,"position":10,"alias":[],"status":0,"fee":0,"copyrightId":0,"disc":"1","no":10,"artists":[{"name":"Claustrophobia","id":11293,"picId":0,"img1v1Id":0,"briefDesc":"","picUrl":"http://p3.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg","img1v1Url":"http://p3.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg","albumSize":0,"alias":[],"trans":"","musicSize":0}],"album":{"name":"Claustrophobic Room 444","id":34461,"type":"专辑","size":11,"picId":127543348825560,"blurPicUrl":"http://p4.music.126.net/Oy-CV8SdvwP0X7sQ1YesMg==/127543348825560.jpg","companyId":0,"pic":127543348825560,"picUrl":"http://p3.music.126.net/Oy-CV8SdvwP0X7sQ1YesMg==/127543348825560.jpg","publishTime":1183219200000,"description":"","tags":"","company":"","briefDesc":"","artist":{"name":"","id":0,"picId":0,"img1v1Id":0,"briefDesc":"","picUrl":"http://p4.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg","img1v1Url":"http://p4.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg","albumSize":0,"alias":[],"trans":"","musicSize":0},"songs":[],"alias":[],"status":1,"copyrightId":0,"commentThreadId":"R_AL_3_34461","artists":[{"name":"Claustrophobia","id":11293,"picId":0,"img1v1Id":0,"briefDesc":"","picUrl":"http://p4.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg","img1v1Url":"http://p4.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg","albumSize":0,"alias":[],"trans":"","musicSize":0}]},"starred":false,"popularity":90,"score":90,"starredNum":0,"duration":355000,"playedNum":0,"dayPlays":0,"hearTime":0,"ringtone":"","crbt":null,"audition":null,"copyFrom":"","commentThreadId":"R_SO_4_349705","rtUrl":null,"ftype":0,"rtUrls":[],"copyright":2,"mvid":0,"bMusic":{"name":null,"id":66318565,"size":5698916,"extension":"mp3","sr":44100,"dfsId":0,"bitrate":128000,"playTime":355000,"volumeDelta":9476},"mp3Url":null,"rtype":0,"rurl":null,"hMusic":{"name":null,"id":66318564,"size":14247226,"extension":"mp3","sr":44100,"dfsId":0,"bitrate":320000,"playTime":355000,"volumeDelta":5411},"mMusic":{"name":null,"id":93643476,"size":8548353,"extension":"mp3","sr":44100,"dfsId":0,"bitrate":192000,"playTime":355000,"volumeDelta":8284},"lMusic":{"name":null,"id":66318565,"size":5698916,"extension":"mp3","sr":44100,"dfsId":0,"bitrate":128000,"playTime":355000,"volumeDelta":9476}},"alg":"alg_search_precision_playlist_tab_tag"},{"id":1980002862,"name":"恐怖","coverImgUrl":"https://p2.music.126.net/F__r6PeA1_TkrhwowkSezg==/18885211719105381.jpg","creator":{"nickname":"Angelia_Wu_","userId":30260625,"userType":0,"authStatus":0,"expertTags":null,"experts":null},"subscribed":false,"trackCount":23,"userId":30260625,"playCount":6,"bookCount":0,"specialType":0,"officialTags":null,"description":"恐怖音乐嗯","highQuality":false,"track":{"name":"Main Titles","id":1161515,"position":2,"alias":[],"status":0,"fee":8,"copyrightId":624010,"disc":"1","no":2,"artists":[{"name":"Charlie Clouser","id":30050,"picId":0,"img1v1Id":0,"briefDesc":"","picUrl":"http://p4.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg","img1v1Url":"http://p4.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg","albumSize":0,"alias":[],"trans":"","musicSize":0}],"album":{"name":"Dead Silence (Original Motion Picture Soundtrack)","id":120131,"type":"专辑","size":30,"picId":109951163316686270,"blurPicUrl":"http://p4.music.126.net/V0yjd54HFkT4yGNNRfJoBw==/109951163316686264.jpg","companyId":0,"pic":109951163316686270,"picUrl":"http://p3.music.126.net/V0yjd54HFkT4yGNNRfJoBw==/109951163316686264.jpg","publishTime":147942720 ...

# %%
search_dict = json.loads(data)

# %%
filename = 'search_data.json'
with open(filename, 'w', encoding='utf-8') as fw:
    json.dump(search_dict, fw, ensure_ascii=False)

# %%
playlist_ids = []

# %%
for item in search_dict['result']['playlists']:
    playlist_ids.append(item.get('id'))

# %%
playlist_ids
# Out:
# [2281417142,
#  1980002862,
#  958308279,
#  523343596,
#  894732534,
#  3024990784,
#  804398604,
#  3052837806,
#  2773061916,
#  2384160921,
#  727511454,
#  2942100597,
#  2875427367,
#  751574722,
#  755820262,
#  24760255,
#  2670081195,
#  319165975,
#  2185568153,
#  133195420,
#  2912419607,
#  2629548393,
#  2700200016,
#  616058242,
#  3008828257,
#  566944868,
#  3208436266,
#  694464994,
#  2186214689,
#  2765624092]

# %%
filename = './playlist_ids.json'
with open(filename, 'r', encoding='utf-8') as fr:
    current_ids = json.load(fr)

# %%
len(current_ids)
# Out:
# 89761

# %%
distinct_list = list(set(current_ids))

# %%
len(distinct_list)
# Out:
# 64062

# %% [markdown]
# # MongoDB存储测试

# %%
import pymongo

# %%
myclient = pymongo.MongoClient("mongodb://192.168.206.100:27017/")

# %%
# 所有数据库列表
dblist = myclient.list_database_names()

# %%
dblist
# Out:
# ['admin', 'local', 'recommender', 'springTest']

# %%
springTest_db = myclient["springTest"]

# %%
springTest_db.collection_names()
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   """Entry point for launching an IPython kernel.
# ['user', 'books']

# %%
# 创建集合，如果集合中没有文档则不存在
mycol = springTest_db["test_play_list"]

# %%
mydict1 = { "name": "RUN", "alexa": "10000", "url": "https://www.runoob.com" }

# %%
# 插入文档，
x = mycol.insert_one(mydict1)

# %%
print(x.inserted_id)
# Out:
# 5fed2eed21fa8a3ef1a6bc39

# %%
mydict2 = { "id": "1", "name": "RUN", "alexa": "10000", "url": "https://www.runoob.com" }

# %%
x = mycol.insert_one(mydict2)

# %%
print(x.inserted_id)
# Out:
# 5fed2fc321fa8a3ef1a6bc3a

# %%
# 指定插入的id
mydict3 = { "_id": "1", "name": "RUN", "alexa": "10000", "url": "https://www.runoob.com" }

# %%
x = mycol.insert_one(mydict3)

# %%
print(x.inserted_id)
# Out:
# 1

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('5fed2eb021fa8a3ef1a6bc38'), 'name': 'RUNOOB', 'alexa': '10000', 'url': 'https://www.runoob.com'}
# {'_id': ObjectId('5fed2eed21fa8a3ef1a6bc39'), 'name': 'RUN', 'alexa': '10000', 'url': 'https://www.runoob.com'}
# {'_id': ObjectId('5fed2fc321fa8a3ef1a6bc3a'), 'id': '1', 'name': 'RUN', 'alexa': '10000', 'url': 'https://www.runoob.com'}
# {'_id': '1', 'name': 'RUN', 'alexa': '10000', 'url': 'https://www.runoob.com'}

# %%
mycol.insert_one(playlist_info_dict)

# %%
mydict3 = {}

# %%
mydict3 = { "id": "2", "name": "RUN", "alexa": "10000", "url": "https://www.runoob.com" }

# %%
mycol.insert_one(mydict3)

# %%
mydict3 = { "_id": "3", "name": "RUN", "alexa": "10000", "url": "https://www.runoob.com" }

# %%
mycol.insert_one(mydict3)

# %%
mydict3["_id"] = "4"

# %%
mycol.insert_one(mydict3)

# %% [markdown]
# 对于同一个python对象，如字典mydict3，如果mydict3没有重新赋值，同时也不指定_id，则出入mongodb会出错，有相同的objectID

# %% [markdown]
# # Python多线程测试

# %%
import threading
import time

def coding():
    for x in range(3):
        print('%s正在写代码' % x)
        time.sleep(1)

def drawing():
    for x in range(3):
        print('%s正在画图' % x)
        time.sleep(1)
    
    
def single_thread():
    start_time = time.time()
    coding()
    drawing()
    end_time = time.time()
    print("运行时间："+str(end_time-start_time))

def multi_thread():
    start_time = time.time()
    t1 = threading.Thread(target=coding)
    t2 = threading.Thread(target=drawing)
    
    t1.start()
    t2.start()
    end_time = time.time()
    print("运行时间："+str(end_time-start_time))

# %%
single_thread()
# Out:
# 0正在写代码
# 1正在写代码
# 2正在写代码
# 0正在画图
# 1正在画图
# 2正在画图
# 运行时间：6.0025599002838135

# %%
multi_thread()
# Out:
# 0正在写代码
# 0正在画图运行时间：0.009995698928833008
#
# 1正在写代码
# 1正在画图
# 2正在写代码
# 2正在画图

# %% [markdown]
# ## 使用类进行封装

# %%
class CodingThread(threading.Thread):
    def run(self):
        for x in range(3):
            print('%s正在写代码' % x)
            time.sleep(1)
            
class DrawingThread(threading.Thread):
    def run(self):
        for x in range(3):
            print('%s正在画图' % x)
            time.sleep(1)

# %%
def multi_thread(): 
    t1 = CodingThread()
    t2 = DrawingThread()
    
    t1.start()
    t2.start()

# %%
start_time = time.time()
multi_thread()
end_time = time.time()
print("运行时间："+str(end_time-start_time))
# Out:
# 0正在写代码
# 0正在画图
# 运行时间：0.009994745254516602
# 1正在写代码
# 1正在画图
# 2正在写代码
# 2正在画图

# %% [markdown]
# ## 锁的机制

# %%
tickets = 0
def get_ticket():
    global tickets
    for x in range(100000):
        tickets += 1
    print('tickets:%d'%tickets)

def main():
    for x in range(3):
        t = threading.Thread(target=get_ticket)
        t.start()

# %%
main()
# Out:
# tickets:100000
# tickets:248464
# tickets:300000

# %% [markdown]
# ## 简单多线程

# %%
import threading
import time

# 为线程定义一个函数
class myThread(threading.Thread):
    def __init__(self, name, delay):
        threading.Thread.__init__(self)
        self.name = name
        self.delay = delay
        
    def run(self):
        print("Starting " + self.name)
        print_time(self.name, self.delay)
        print("Exiting " + self.name)
        
def print_time(threadNmae, delay):
    counter = 0
    while counter < 3:
        time.sleep(delay)
        print(threadNmae, time.ctime())
        counter += 1

# %%
threads = []

# 创建新线程
thread1 = myThread(name="Thread-1", delay=1)
thread2 = myThread(name="Thread-2", delay=2)

# 开启新线程
thread1.start()
thread2.start()

# 添加新线程到线程列表
threads.append(thread1)
threads.append(thread2)

# 等待所有线程完成
for t in threads:
    t.join()
    
print("Exiting Main Thread")
# Out:
# Starting Thread-1
# Starting Thread-2
# Thread-1 Thu Dec 31 11:48:33 2020
# Thread-1 Thu Dec 31 11:48:34 2020
# Thread-2 Thu Dec 31 11:48:34 2020
# Thread-1 Thu Dec 31 11:48:35 2020
# Exiting Thread-1
# Thread-2 Thu Dec 31 11:48:36 2020
# Thread-2 Thu Dec 31 11:48:38 2020
# Exiting Thread-2
# Exiting Main Thread

# %%
a = ['as', 'as', 'ss', 'er', '34']
b = {}

# %%
for index, item in enumerate(a):
    print(str(index) + ": "+ item)
    b[index] = item
# Out:
# 0: as
# 1: as
# 2: ss
# 3: er
# 4: 34

# %%
print(b)
# Out:
# {0: 'as', 1: 'as', 2: 'ss', 3: 'er', 4: '34'}

# %%
from tqdm import tqdm

pbar = tqdm(["a", "b", "c", "d"], leave=True)
for char in pbar:
#     pbar.set_description("Now Processing %s" % char) #这里的这个方法就相当于给tqdm类的构造函数添加一个 desc 参数
    time.sleep(0.2)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.91it/s]
